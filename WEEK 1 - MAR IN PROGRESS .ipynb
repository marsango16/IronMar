# %%
# HELLO WORLD

# %%
# My purpose of this notebook will be introducing someone holidays
name = input("Enter Name: ")
print("name")
# Out:
# Enter Name: Obama
# name

# %% [markdown]
# ![descarga.jpeg](attachment:descarga.jpeg)

# %% [markdown]
# ![descarga%20%281%29.jpeg](attachment:descarga%20%281%29.jpeg)

# %% [markdown]
# - He likes to eat paella
# - He likes danzing flamenco
# - He likes swimming at the beach

# %%
<span style='color:Blue'> Hello world  </span>
# Out:
#   File "/var/folders/9_/q2nj061x7q7_cmq16rjp2c400000gn/T/ipykernel_6711/374810818.py", line 1
#     <span style='color:Blue'> Hello world  </span>
#     ^
# SyntaxError: invalid syntax

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/xaFIBS3V9s4" title="YouTube video player"</iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/xaFIBS3V9s4" title="YouTube video player"</iframe>
