# %%
# 1. Aggregate the data into one Data Frame using Pandas. Pay attention that files may have different names for the same column. therefore, make sure that you unify the columns names before concating them.
# 2. Standardizing header names
# 3. Removing duplicates

# Define file paths
file1 = 'file1.csv'
file2 = 'file2.csv'
file3 = 'file3.csv'

# Read CSV files
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)

df1 = df1.rename(columns= lambda x: x.lower())
df2 = df2.rename(columns= lambda x: x.lower())
df3 = df3.rename(columns= lambda x: x.lower())

def rename_columns(*dataframes):
    for df in dataframes:
        if 'st' in df.columns:
            df.rename(columns={'st': 'state'}, inplace=True)
    return dataframes


df1, df2, df3 = rename_columns(df1, df2, df3)

customer_df = pd.concat([df1, df2, df3])

customer_df
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
# Deleting and rearranging columns
# Delete the column customer as it is only a unique identifier for each row of data


# customer_df.drop('Customer', inplace=True, axis=1)
# print(customer_df.drop)

import pandas as pd

# Define file paths
file1 = 'file1.csv'
file2 = 'file2.csv'
file3 = 'file3.csv'

# Read CSV files and handle errors
try:
    df1 = pd.read_csv(file1)
    df2 = pd.read_csv(file2)
    df3 = pd.read_csv(file3)
except FileNotFoundError:
    print("Error: One or more files not found")
    exit()

# Convert column names to lowercase
df1 = df1.rename(columns=lambda x: x.lower())
df2 = df2.rename(columns=lambda x: x.lower())
df3 = df3.rename(columns=lambda x: x.lower())

# Rename 'st' column to 'state' if present
def rename_columns(*dataframes):
    for df in dataframes:
        if 'st' in df.columns:
            df.rename(columns={'st': 'state'}, inplace=True)
    return dataframes

df1, df2, df3 = rename_columns(df1, df2, df3)

# Concatenate DataFrames
customer_df = pd.concat([df1, df2, df3])

# Delete the 'customer' column
customer_df.drop('customer', axis=1, inplace=True)

customer_df
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
# Working with data types – Check the data types of all the columns and fix the incorrect ones 
# (for ex. customer lifetime value and number of open complaints)
# Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.

import pandas as pd
import numpy as np

# Define file paths
file1 = 'file1.csv'
file2 = 'file2.csv'
file3 = 'file3.csv'

# Read CSV files and handle errors
try:
    df1 = pd.read_csv(file1)
    df2 = pd.read_csv(file2)
    df3 = pd.read_csv(file3)
except FileNotFoundError:
    print("Error: One or more files not found")
    exit()

# Convert column names to lowercase
df1 = df1.rename(columns=lambda x: x.lower())
df2 = df2.rename(columns=lambda x: x.lower())
df3 = df3.rename(columns=lambda x: x.lower())

# Rename 'st' column to 'state' if present
def rename_columns(*dataframes):
    for df in dataframes:
        if 'st' in df.columns:
            df.rename(columns={'st': 'state'}, inplace=True)
    return dataframes

df1, df2, df3 = rename_columns(df1, df2, df3)

# Concatenate DataFrames
customer_df = pd.concat([df1, df2, df3])

# Delete the 'customer' column
customer_df.drop('customer', axis=1, inplace=True)

# Extract the "customer lifetime value" column as a pandas Series object
customer_lifetime_value = customer_df['customer lifetime value']

customer_df
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor             23405.98798
# 7066  California      F               College             3096.511217
# 7067  California      M              Bachelor             8163.890428
# 7068  California      M               College             7524.442436
# 7069  California      M               College             2611.836866
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
customer_df['customer lifetime value'].isna().sum()
# Out:
# 2944

# %%
customer_df['customer lifetime value'].apply(type).value_counts()
# Out:
# <class 'float'>    10014
# <class 'str'>       2060
# Name: customer lifetime value, dtype: int64

# %%
customer_df['customer lifetime value'].dtypes
customer_df['customer lifetime value']=customer_df['customer lifetime value'].str.replace("%", "")
customer_df
# Out:
#            state gender             education customer lifetime value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065  California      M              Bachelor                     NaN
# 7066  California      F               College                     NaN
# 7067  California      M              Bachelor                     NaN
# 7068  California      M               College                     NaN
# 7069  California      M               College                     NaN
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
customer_df['customer lifetime value']=customer_df['customer lifetime value'].fillna(0).astype(float).round()
customer_df
# Out:
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      0.0
# 1        Arizona      F              Bachelor                 697954.0
# 2         Nevada      F              Bachelor                1288743.0
# 3     California      M              Bachelor                 764586.0
# 4     Washington      M  High School or Below                 536308.0
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor                      0.0
# 7066  California      F               College                      0.0
# 7067  California      M              Bachelor                      0.0
# 7068  California      M               College                      0.0
# 7069  California      M               College                      0.0
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
customer_df['number of open complaints'].apply(type).value_counts()
# Out:
# <class 'int'>      7070
# <class 'float'>    2937
# <class 'str'>      2067
# Name: number of open complaints, dtype: int64

# %%
def extract_number (x):
    if isinstance(x, str) and "/" in x: 
        return x.split("/")[1]
    elif x == np.nan:
        pass
    else:
        return x
    
customer_df['number of open complaints']=customer_df['number of open complaints'].apply(extract_number)
customer_df
# Out:
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      0.0
# 1        Arizona      F              Bachelor                 697954.0
# 2         Nevada      F              Bachelor                1288743.0
# 3     California      M              Bachelor                 764586.0
# 4     Washington      M  High School or Below                 536308.0
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor                      0.0
# 7066  California      F               College                      0.0
# 7067  California      M              Bachelor                      0.0
# 7068  California      M               College                      0.0
# 7069  California      M               College                      0.0
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
customer_df['state'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
#clean function for state column

def cleandata(i):
    if i == 'AZ':
        i = 'Arizona'
    elif i == 'WA':
        i = 'Washington'
    elif i == 'Cali':
        i = 'California'
    return i

# cleaned state 
customer_df["state"] = customer_df["state"].apply(clean_data)
customer_df
# Out:
#            state gender             education  customer lifetime value  \
# 0     Washington    NaN                Master                      0.0
# 1        Arizona      F              Bachelor                 697954.0
# 2         Nevada      F              Bachelor                1288743.0
# 3     California      M              Bachelor                 764586.0
# 4     Washington      M  High School or Below                 536308.0
# ...          ...    ...                   ...                      ...
# 7065  California      M              Bachelor                      0.0
# 7066  California      F               College                      0.0
# 7067  California      M              Bachelor                      0.0
# 7068  California      M               College                      0.0
# 7069  California      M               College                      0.0
#
#        income  monthly premium auto number of open complaints     policy type  \
# ...

# %%
customer_df['state'].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon', 'Cali',
#        'AZ', 'WA', nan], dtype=object)

# %%
customer_df['gender'].unique()
# Out:
# array([nan, 'F', 'M', 'Femal', 'Male', 'female'], dtype=object)

# %%
def clean_data(i):
    if i == 'F':
        i = 'Female'
    elif i == 'M':
        i = 'Male'
    elif i == 'Femal' or i == 'female':
        i = 'Female'
    return i

# cleaned gender column
customer_df["gender"] = customer_df["gender"].apply(clean_data)
customer_df
# Out:
#     customer      region  gender education customer lifetime value  income  \
# 0    GS98873     Arizona  Female  Bachelor              323912.47%   16061
# 1    CW49887  California  Female    Master              462680.11%   79487
# 2    MY31220  California  Female   College              899704.02%   54230
# 3    UH35128      Oregon  Female   College             2580706.30%   71210
# 4    WH52799     Arizona  Female   College              380812.21%   94903
# ..       ...         ...     ...       ...                     ...     ...
# 991  HV85198     Arizona    Male    Master              847141.75%   63513
# 992  BS91566     Arizona  Female   College              543121.91%   58161
# 993  IL40123      Nevada  Female   College              568964.41%   83640
# 994  MY32149  California  Female    Master              368672.38%       0
# 995  SA91515  California    Male  Bachelor              399258.39%       0
#
# ...

# %%
customer_df['income'].unique
# Out:
# <bound method Series.unique of 0      16061
# 1      79487
# 2      54230
# 3      71210
# 4      94903
#        ...
# 991    63513
# 992    58161
# 993    83640
# 994        0
# 995        0
# Name: income, Length: 996, dtype: int64>

# %%
customer_df['income'] = customer_df['income'].fillna(0).astype(float).round()
customer_df['income'] = customer_df['income'].fillna(customer_df['income'].mean())
customer_df
# Out:
#     customer      region  gender education customer lifetime value   income  \
# 0    GS98873     Arizona  Female  Bachelor              323912.47%  16061.0
# 1    CW49887  California  Female    Master              462680.11%  79487.0
# 2    MY31220  California  Female   College              899704.02%  54230.0
# 3    UH35128      Oregon  Female   College             2580706.30%  71210.0
# 4    WH52799     Arizona  Female   College              380812.21%  94903.0
# ..       ...         ...     ...       ...                     ...      ...
# 991  HV85198     Arizona    Male    Master              847141.75%  63513.0
# 992  BS91566     Arizona  Female   College              543121.91%  58161.0
# 993  IL40123      Nevada  Female   College              568964.41%  83640.0
# 994  MY32149  California  Female    Master              368672.38%      0.0
# 995  SA91515  California    Male  Bachelor              399258.39%      0.0
#
# ...

# %%
customer_df['income'] = customer_df['income'].fillna(customer_df['income'].mean())
customer_df
# Out:
#     customer      region  gender education customer lifetime value   income  \
# 0    GS98873     Arizona  Female  Bachelor              323912.47%  16061.0
# 1    CW49887  California  Female    Master              462680.11%  79487.0
# 2    MY31220  California  Female   College              899704.02%  54230.0
# 3    UH35128      Oregon  Female   College             2580706.30%  71210.0
# 4    WH52799     Arizona  Female   College              380812.21%  94903.0
# ..       ...         ...     ...       ...                     ...      ...
# 991  HV85198     Arizona    Male    Master              847141.75%  63513.0
# 992  BS91566     Arizona  Female   College              543121.91%  58161.0
# 993  IL40123      Nevada  Female   College              568964.41%  83640.0
# 994  MY32149  California  Female    Master              368672.38%      0.0
# 995  SA91515  California    Male  Bachelor              399258.39%      0.0
#
# ...

# %%
def replace(i):
    if i == "California":
        return "West Region"
    elif i == "Oregon":
        return "North West"
    elif i == "Washington":
        return "East"
    elif i == "Arizona" or "Nevada":
        return "Central"
    else:
        return i

# %%
customer_df = customer_df.rename(columns={'state': 'region'})
customer_df["region"] = list(map(replace, customer_df["region"]))
customer_df
# Out:
#     customer       region  gender education customer lifetime value   income  \
# 0    GS98873      Central  Female  Bachelor              323912.47%  16061.0
# 1    CW49887  West Region  Female    Master              462680.11%  79487.0
# 2    MY31220  West Region  Female   College              899704.02%  54230.0
# 3    UH35128   North West  Female   College             2580706.30%  71210.0
# 4    WH52799      Central  Female   College              380812.21%  94903.0
# ..       ...          ...     ...       ...                     ...      ...
# 991  HV85198      Central    Male    Master              847141.75%  63513.0
# 992  BS91566      Central  Female   College              543121.91%  58161.0
# 993  IL40123      Central  Female   College              568964.41%  83640.0
# 994  MY32149  West Region  Female    Master              368672.38%      0.0
# 995  SA91515  West Region    Male  Bachelor              399258.39%      0.0
#
# ...
